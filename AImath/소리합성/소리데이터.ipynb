# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
import os

# sampling rate 1초를 몇개로 쪼개느냐
Fs = 48000.0

tlen = 3

Ts = 1/Fs
print(len(t))
x_list = np.arange(0, tlen, Ts) # x값
freq = 440
y_list = np.sin(2*np.pi*247*x_list)
# y2_list = np.sin(2*np.pi*294*x_list)
# y3_list = np.sin(2*np.pi*392*x_list)

# y_list = y1_list + y2_list + y3_list
plt.plot(x_list[:300], y_list[:300], color = 'blue')
# Out:
# 144000

# %%
scaled = np.int16(y_list*32767)
write('440.wav', 4800, scaled)
